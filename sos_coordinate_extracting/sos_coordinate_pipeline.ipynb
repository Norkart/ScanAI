# %%
"""
This script handles coordinate transformations using a custom DLL (`skt2_1507-1504_1.dll`) 
and a reference file (`HREF2018B_NN2000_EUREF89.bin`). It reads pairs of `.jpg` and `.sos` 
files, extracts the bounding coordinates from the `.sos` file, optionally transforms 
them from the Ålesund coordinate system to EUREF89 (using the DLL), and writes out a 
world file (`.jgw`) that allows GIS software to georeference the `.jpg`.

Important notes:
- The DLL (`skt2_1507-1504_1.dll`) and the reference file (`HREF2018B_NN2000_EUREF89.bin`)
  are expected to be for a Windows 32-bit environment that requires certain steps 
  for the transformation to succeed (e.g., correct paths, correct architecture).
- The script uses `ctypes` to interface with the DLL.
- The `.sos` file is assumed to contain lines specifying KoordSys, and coordinate pairs 
  under the `..NØ` marker.
"""

import os
import re
from PIL import Image
import ctypes


def parse_sos_file(sos_file_path):
    """
    Parse a `.sos` file to extract:
    1) The coordinate system (koordsys), if specified after '...KOORDSYS'
    2) The coordinate pairs after '..NØ'
    Returns:
        koordsys (int or None)
        coordinates (list of (float, float))
    """

    koordsys = None
    coordinates = []
    inside_coordinates = False

    # Open the .sos file in ISO8859-10 encoding.
    with open(sos_file_path, 'r', encoding='ISO8859-10') as f:
        for line in f:
            line = line.strip()
            # Find the line starting with ...KORDSYS to get the coordinate system number.
            if line.startswith('...KOORDSYS'):
                parts = line.split()
                if len(parts) >= 2:
                    koordsys = int(parts[1])
            # Find the line starting with ..NØ to get the coordinates on the subsequent lines.
            if line.startswith('..NØ'):
                inside_coordinates = True
                continue
            # If we are inside the coordinate section, parse the x and y coordinates as floats.
            if inside_coordinates:
                if re.match(r'^\d+\s+\d+$', line):
                    x, y = line.split()
                    coordinates.append((float(x), float(y)))
                else:
                    break

    return koordsys, coordinates


def initialize_transformation(dll_path, href_file):
    """
    Load the DLL at 'dll_path', then initialize the transformation with 'href_file'.
    Raises FileNotFoundError if either is missing.
    Raises RuntimeError if the DLL initialization fails (sErr != 0).
    Returns the DLL handle and references to _InitSkTrans and _GeoTrans functions.
    """

    # Check if the DLL file exists.
    if not os.path.exists(dll_path):
        raise FileNotFoundError("DLL file not found.")
    # Check if the HREF file exists.
    if not os.path.exists(href_file):
        raise FileNotFoundError("HREF file not found.")
    
    # Load the DLL with ctypes.
    trans_dll = ctypes.CDLL(dll_path)

    # Prepare references to the initialization function.
    _InitSkTrans = trans_dll._InitSkTrans
    _InitSkTrans.argtypes = [ctypes.c_char_p, ctypes.POINTER(ctypes.c_short), ctypes.POINTER(ctypes.c_short)]
    _InitSkTrans.restype = None

    # Encode HREF file path in utf-8 for passing to DLL.
    href = href_file.encode('utf-8')
    sLen = ctypes.c_short(len(href))
    sErr = ctypes.c_short(0)

    # Call the initialization function.
    _InitSkTrans(href, ctypes.byref(sLen), ctypes.byref(sErr))

    # Check if there was an error.
    if sErr.value != 0:
        raise RuntimeError(f"Failed to initialize transformation. Error Code: {sErr.value}")

    #Return references to the DLL file, the initialization function, and the main transformation function.
    return trans_dll, _InitSkTrans, trans_dll._GeoTrans


def transform_aalesund_to_euref(x, y, _GeoTrans, slSys1, slZone1, slSys2, slZone2):
    """
    Transform a single (x, y) from Ålesund's local system (Sys=4, Zone=1) to EUREF89 (Sys=7, Zone=32).
    _GeoTrans is the DLL's transformation function.
    The returned coordinates are (lat, lon) or (northing, easting), depending on the system.
    Raises RuntimeError if the transformation fails.
    """

    # Prepare input/outputs as ctypes doubles.
    x1 = ctypes.c_double(x)
    y1 = ctypes.c_double(y)
    z1 = ctypes.c_double(0.0)
    x2 = ctypes.c_double(0.0)
    y2 = ctypes.c_double(0.0)
    z2 = ctypes.c_double(0.0)
    slErr = ctypes.c_short(0)

    # Call the transformation function.
    _GeoTrans(
        ctypes.byref(slSys1), ctypes.byref(slZone1),
        ctypes.byref(x1), ctypes.byref(y1), ctypes.byref(z1),
        ctypes.byref(slSys2), ctypes.byref(slZone2),
        ctypes.byref(x2), ctypes.byref(y2), ctypes.byref(z2),
        ctypes.byref(slErr)
    )

    # Check for errors.
    if slErr.value != 0:
        raise RuntimeError(f"Transformation failed. Error Code: {slErr.value}")

    # Return the new coordinates containing northing and easting.
    return y2.value, x2.value


def create_world_file(image_path, x_min_trans, y_min_trans, x_max_trans, y_max_trans):
    """
    Create a .jgw (world file) based on an image's width/height and bounding coordinates.
    Args:
        image_path     : path to the .jpg image
        x_min_trans    : transformed min X (easting)
        y_min_trans    : transformed min Y (northing)
        x_max_trans    : transformed max X (easting)
        y_max_trans    : transformed max Y (northing)
    The .jgw file is named the same as the image but with .jgw extension.
    """

    # Open the image to get the width and height.
    img = Image.open(image_path)
    width, height = img.size

    # Pixel size in X range.
    pixel_size_x = (x_max_trans - x_min_trans) / width
    # Pixel size in Y range.
    pixel_size_y = (y_min_trans - y_max_trans) / height

    # Top-left corner in easting/northing.
    top_left_easting = x_min_trans
    top_left_northing = y_max_trans

    # Construct world-file path.
    world_file_path = os.path.splitext(image_path)[0] + ".jgw"
    # Write out the 6 lines of the world file.
    with open(world_file_path, 'w') as wf:
        wf.write(f"{pixel_size_x}\n")
        wf.write("0.0\n")
        wf.write("0.0\n")
        wf.write(f"{pixel_size_y}\n")
        wf.write(f"{top_left_easting}\n")
        wf.write(f"{top_left_northing}\n")

    print(f"World file created: {world_file_path}")


def process_folder(base_folder, dll_path, href_file):
    """
    Traverse all subfolders within 'base_folder'. 
    For each .jpg that has a matching .sos (same basename), parse the .sos for 2 coords.
    If KoordSys=110, transform from Ålesund local to EUREF. 
    Then create a .jgw (world file) so GIS software can georeference the .jpg.
    """

    # Walk through the base folder structure.
    for root, _, files in os.walk(base_folder):
        # Build dictionaries for .jpg and .sos by filename.
        jpg_files = {os.path.splitext(f)[0]: os.path.join(root, f) for f in files if f.endswith(".jpg")}
        sos_files = {os.path.splitext(f)[0]: os.path.join(root, f) for f in files if f.endswith(".sos")}

        # Find basenames that exist in both sets.
        matching_files = set(jpg_files.keys()) & set(sos_files.keys())
        for match in matching_files:
            jpg_path = jpg_files[match]
            sos_path = sos_files[match]

            # Parse the .sos file for coordinate system and coordinates.
            koordsys, coords = parse_sos_file(sos_path)
            if len(coords) != 2:
                print(f"Skipping {sos_path} - Invalid coordinate pairs")
                continue

            # Unpack the two coordinates pairs (x_min, y_min), (x_max, y_max)
            (x_min, y_min), (x_max, y_max) = coords
            x_min, x_max = sorted([x_min, x_max])
            y_min, y_max = sorted([y_min, y_max])

            # If the coordinate system is 110, do custom transformation, else use the coordinates as is.
            if koordsys == 110:
                try:
                    # Initialize the transformation library.
                    trans_dll, _InitSkTrans, _GeoTrans = initialize_transformation(dll_path, href_file)

                    # Set up the system codes for the DLL.
                    slSys1 = ctypes.c_short(4) # Source system.
                    slZone1 = ctypes.c_short(1)
                    slSys2 = ctypes.c_short(7) # Target system (EUREF).
                    slZone2 = ctypes.c_short(32)

                    # Helper function to transform a single .sos/.jpg pair.
                    def transform(x, y):
                        return transform_aalesund_to_euref(x, y, _GeoTrans, slSys1, slZone1, slSys2, slZone2)

                    # Transform both corners.
                    easting_min, northing_min = transform(x_min, y_min)
                    easting_max, northing_max = transform(x_max, y_max)
                except RuntimeError as e:
                    print(f"Error transforming {sos_path}: {e}")
                    continue
            else:
                # If the coordinate system is not 110, just use the coordinates as is.
                easting_min, northing_min = x_min, y_min
                easting_max, northing_max = x_max, y_max

            # Create the new .jgw world file.
            create_world_file(jpg_path, easting_min, northing_min, easting_max, northing_max)


if __name__ == "__main__":
    base_folder = "../dataset"
    dll_path = r"skt2_1507-1504_1.dll"
    href_file = r"HREF2018B_NN2000_EUREF89.bin"

    process_folder(base_folder, dll_path, href_file)
# Out:
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200h.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504200\200i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201k.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201h.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201j.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201l.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504201\201i.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504209\209t.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209q.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209v.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209o.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209h.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209k.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209u.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209n.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209p.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209l.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504209\209a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504212\212.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504213\213.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504217\217.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504220\220.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504221A\221a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504224\224.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504225\225.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504225\225a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504228\228a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504228\228e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504228\228.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504228\228d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504229\229c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504230\230.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504231A_B_D\231d.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504231A_B_D\231a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504231A_B_D\231b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504234\234.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504237\237g.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504237\237c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504238A_C_D\238d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504238A_C_D\238a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504238A_C_D\238c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504239\239.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504240\240b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504240\240.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504241\241.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504243\243.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504245\245.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504247\247.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504248A\248a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504249\249.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504250\250a.jgw
# c:\Users\SivertEspelandHusebø\python32\Lib\site-packages\PIL\Image.py:3402: DecompressionBombWarning: Image size (171714688 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# World file created: ../dataset\dataset\aalesund\FOKUS\1504250\250.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504250\250c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504251\251.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504252\252.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504256\256.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504261\261a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504261\261.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504262A\262a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263j.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263l.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263k.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263m.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504263\263h.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504264\264a.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504264\264.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504266\266.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504267\267.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504268\268d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504268\268a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504268\268.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504268\268c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504268\268b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504270\270.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504270\270c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504270\270b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504271\271.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504274\274.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504276\276a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504276\276.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504277\277.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504277\277a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504278\278.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504279\279.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504280\280.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504280\280a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504282\282.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504283\283.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504285\285.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504287\287.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504288\288.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290h.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504290\290f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504292\292.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504294\294.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504296\296.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504299\299.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504299\299a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504299\299c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504299\299b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300p.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300j.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504300\300x.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300u.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300i.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300h.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300m.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300r.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300o.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300q.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300n.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300g.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300t.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504300\300l.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504300\300v.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504302\302d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504302\302c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504302\302a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504302\302b.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504302\302f.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504302\302.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504304\304.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504304\304a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504307A\307a.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504309\309c.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504309\309b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504309\309.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504312\312.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504313\313.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504314\314.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504316\316.jgw
# Skipping ../dataset\dataset\aalesund\FOKUS\1504317\317b.sos - Invalid coordinate pairs
# World file created: ../dataset\dataset\aalesund\FOKUS\1504317\317a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504317\317.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504318\318.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504319\319f.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504319\319.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504319\319b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504319\319a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504319\319j.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504320\320.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504320\320a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504321\321.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504322\322.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504323\323.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504324\324.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504324\324a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504325\325.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504327\327.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504329\329.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504330\330.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332b.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332f.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332n.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332l.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332d.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332o.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504332A_B_D_F_L_N_O_Q\332q.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504334\334b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504334\334a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504334\334.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504335\335.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504336\336.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504337\337.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504338\338.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504339\339a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504339\339.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504340\340.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504341\341.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504343\343.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504344\344.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504345\345.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504347\347.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504347\347b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504347\347a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504351\351.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504352\352b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504352\352.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504353\353.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504353\353a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504356\356.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357f.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357c.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357d.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504357\357b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504358\358.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504360\360.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504360\360a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504361\361.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504363\363.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504364\364.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504365\365a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504365\365.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504366\366a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504366\366c.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504366\366.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504367\367.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504368\368.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504371\371a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504371\371.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504374\374.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504374\374a.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504374\374b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377c.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377e.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377d.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504377\377.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504378\378.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504379\379.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504379\379a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504380\380.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504381\381.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504383\383.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504384\384.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504386\386.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504388\388a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504388\388.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504395\395.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504395\395a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504396\396.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504397\397.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504398\398.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504400\400.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504401\401c.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504401\401a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504401\401.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504403\403.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504406\406.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504408\408.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504408\408a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504409\409.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504411\411f.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504411\411c.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504411\411b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504411\411.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504412\412.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504412\412b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504413A_B\413a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504413A_B\413b.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504414\414.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504415\415.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504416\416.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504417\417.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504418\418.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504419\419a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504419\419.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504421\421a.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504421\421b.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504421\421.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504425\425.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504426\426.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504428A\428a.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504429\429.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504430\430.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504431\431.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504432\432.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504433\433a.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504433\433.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504434\434.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504435\435a.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504435\435.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504438\438a.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504438\438.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504440\440.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504441\441.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504444\444.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504455\455.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504469\469.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504474\474.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\FOKUS\1504477\477.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504486\486.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504487\487.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504497\497.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504498\498.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504507\507.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504526\526.jgw
# World file created: ../dataset\dataset\aalesund\FOKUS\1504527\527.jgw
# Error transforming ../dataset\dataset\aalesund\FOKUS\1504545\545.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504332C\332c.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504332E\332e.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504332I\332i.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504332J\332j.sos: Transformation failed. Error Code: 19
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504332K\332k.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504354A\354a.jgw
# Error transforming ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504412A\412a.sos: Transformation failed. Error Code: 19
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504426A\426a.jgw
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504426B\426b.jgw
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Bebyggelsesplan\1504439\439.jgw
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Delvis fargelagt\1504447\447.jgw
# World file created: ../dataset\dataset\aalesund\UTFORDRING\Monokrom\1504343A\343a.jgw
