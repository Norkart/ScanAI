# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image
import os
import cv2
import supervision as sv
from supervision.draw.color import Color, ColorPalette
from shapely.geometry import Polygon
from PIL import Image
import gc
from samgeo import SamGeo2
from samgeo.hq_sam import (
    SamGeo,
    show_image,
    download_file,
    overlay_images,
    tms_to_geotiff,
)

#os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Collect garbage
#gc.collect()

# Free up GPU memory
#torch.cuda.empty_cache()


# use bfloat16 for the entire notebook
torch.autocast(device_type="cuda", dtype=torch.float16).__enter__()
 
if torch.cuda.get_device_properties(0).major >= 8:
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
# Out:
# /home/siverteh/miniconda/lib/python3.12/site-packages/sam2/modeling/sam/transformer.py:23: UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.
#   OLD_GPU, USE_FLASH_ATTN, MATH_KERNEL_ON = get_sdpa_settings()
# /home/siverteh/miniconda/lib/python3.12/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_5m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_5m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /home/siverteh/miniconda/lib/python3.12/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_11m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_11m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /home/siverteh/miniconda/lib/python3.12/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /home/siverteh/miniconda/lib/python3.12/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_384 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /home/siverteh/miniconda/lib/python3.12/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_512 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_512. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)

# %%
def show_anns(anns, borders=True):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)
 
    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:,:,3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.5]])
        img[m] = color_mask 
        if borders:
            import cv2
            contours, _ = cv2.findContours(m.astype(np.uint8),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
            # Try to smooth contours
            contours = [cv2.approxPolyDP(contour, epsilon=0.01, closed=True) for contour in contours]
            cv2.drawContours(img, contours, -1, (0,0,1,0.4), thickness=1) 
 
    ax.imshow(img)

# %%
# Load the image
image_bgr = cv2.imread('ScanAI/datasets/aalesund/1504200/200.jpg')
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
"""mask_generator = SamGeo2(
    model_id="sam2-hiera-large",        # Best for large, detailed tasks.
    automatic=True,                    # Enable automatic mask generation.
    apply_postprocessing=True,         # Clean up masks for smoother edges.
    points_per_side=128,               # Denser grid to ensure detailed masks.
    points_per_batch=64,               # Higher batch size for efficiency.
    pred_iou_thresh=0.75,               # Medium IOU threshold to merge similar regions.
    stability_score_thresh=0.85,       # Lower stability threshold to allow more masks.
    stability_score_offset=1.0,        # Standard offset for stability.
    mask_threshold=0.0,                # Threshold for binarizing mask logits.
    box_nms_thresh=0.7,                # Reduce overlap for distinct regions.
    crop_n_layers=0,                   # Single crop layer for large maps.
    crop_nms_thresh=0.7,               # Ensure non-maximal suppression between crops.
    crop_overlap_ratio=0.3,            # Overlap between crops to catch edges.
    crop_n_points_downscale_fa7ctor=1,  # No downscaling for consistent mask detail.
    min_mask_region_area=100,          # Remove very small noise regions.
    output_mode="binary_mask",         # Binary masks are efficient for visualization.
    use_m2m=True,                      # Enable refinement for cleaner masks.
    multimask_output=False,             # Output multiple masks per region for robustness.
    max_hole_area=0.0,                  # Fill small holes within masks.
    max_sprinkle_area=0.0               # Remove small noise (sprinkles) in masks.
)"""

sam_kwargs = {
    "points_per_side": 256,  # High density of points for detailed mask generation
    "points_per_batch": 16,  # Larger batch size for processing more points
    "pred_iou_thresh": 0.8,  # Balanced IoU threshold to favor larger, accurate masks
    "stability_score_thresh": 0.9,  # Slightly reduced for stable yet inclusive masks
    "stability_score_offset": 1.0,  # Standard offset to stabilize score calculation
    "box_nms_thresh": 0.7,  # Reduce overlap suppression to retain neighboring areas
    "crop_n_layers": 1,  # Enable one layer of cropping for large regions
    "crop_nms_thresh": 0.5,  # Lower NMS for more overlapping crops
    "crop_overlap_ratio": 0.5,  # Moderate overlap to balance precision and size
    "crop_n_points_downscale_factor": 1,  # No downscaling for detailed crops
    "point_grids": None,  # Leave point grids to be generated automatically
    "min_mask_region_area": 20,  # Ignore very small regions to focus on larger areas
    "output_mode": "binary_mask",  # Binary masks for clear segmentation
}


mask_generator = SamGeo(
    model_type="vit_h",
    sam_kwargs=sam_kwargs,
)
# Out:
# <All keys matched successfully>

# %%
mask_generator.generate(image_rgb)
sam_result = mask_generator.masks
print(len(sam_result))
# Out:
# 302

# %%
# Import necessary modules
import numpy as np

# Define function to check if one mask is completely inside another
def is_mask_inside(outer_mask, inner_mask):
    # Check if all True pixels in inner_mask are also True in outer_mask
    return np.all(outer_mask[inner_mask > 0])

# Step 1: Extract masks, compute area, and compute bounding boxes for sorting
# Include the index to reference back to `sam_result`
masks_with_areas_and_bboxes = []
for i, mask in enumerate(sam_result):
    segmentation = mask['segmentation']
    if np.any(segmentation):
        area = np.sum(segmentation)
        # Compute bounding box
        coords = np.argwhere(segmentation)
        y_coords, x_coords = coords[:, 0], coords[:, 1]
        min_x, max_x = x_coords.min(), x_coords.max()
        min_y, max_y = y_coords.min(), y_coords.max()
        bbox = (min_x, min_y, max_x, max_y)
        masks_with_areas_and_bboxes.append((i, segmentation, area, bbox))

# Sort masks by area (from largest to smallest)
masks_with_areas_and_bboxes.sort(key=lambda x: x[2], reverse=True)  # (index, mask, area, bbox)

# Set the threshold for the minimum number of contained masks required to remove a mask
contained_mask_threshold = int(0.5 * len(masks_with_areas_and_bboxes))

# Identify masks to remove
indices_to_remove = set()

# Loop through masks and remove larger masks that contain multiple smaller masks
for i, (outer_idx, outer_mask, outer_area, outer_bbox) in enumerate(masks_with_areas_and_bboxes):
    outer_min_x, outer_min_y, outer_max_x, outer_max_y = outer_bbox
    contained_count = 0  # Counter for masks contained within the current outer mask

    # Only consider smaller masks
    for inner_idx, inner_mask, inner_area, inner_bbox in masks_with_areas_and_bboxes[i+1:]:
        inner_min_x, inner_min_y, inner_max_x, inner_max_y = inner_bbox

        # Check if inner bounding box is entirely within outer bounding box
        if (inner_min_x >= outer_min_x and inner_max_x <= outer_max_x and
            inner_min_y >= outer_min_y and inner_max_y <= outer_max_y):
            # Now check if inner_mask is inside outer_mask
            if is_mask_inside(outer_mask, inner_mask):
                contained_count += 1  # Increment count for each contained mask

    # Only mark the larger mask for removal if it contains at least `contained_mask_threshold` smaller masks
    if contained_count >= contained_mask_threshold:
        indices_to_remove.add(outer_idx)

# Filter out the unwanted masks
filtered_masks_with_areas_and_bboxes = [
    (idx, mask, area, bbox)
    for idx, mask, area, bbox in masks_with_areas_and_bboxes
    if idx not in indices_to_remove
]

# Also remove any masks that cover the entire image (if any)
image_area = image_bgr.shape[0] * image_bgr.shape[1]
filtered_masks_with_areas_and_bboxes = [
    (idx, mask, area, bbox)
    for idx, mask, area, bbox in filtered_masks_with_areas_and_bboxes
    if area < image_area
]

# Create a filtered sam_result
filtered_sam_result = [sam_result[idx] for idx, _, _, _ in filtered_masks_with_areas_and_bboxes]

# Get the sorted masks
"""sorted_masks = [mask for _, mask, _, _ in filtered_masks_with_areas_and_bboxes]

# Define custom function to find the mode of an array
def custom_mode(array):
    values, counts = np.unique(array, return_counts=True)
    return values[np.argmax(counts)]

# Function to get the most common color within a masked area
def get_most_common_color(image_bgr, mask):
    mask_area = np.where(mask)
    pixels = image_bgr[mask_area]
    if pixels.size == 0 or pixels.ndim != 2 or pixels.shape[1] != 3:
        return (0, 0, 0)

    # Use custom mode for each channel (BGR order)
    b_mode = int(custom_mode(pixels[:, 0]))
    g_mode = int(custom_mode(pixels[:, 1]))
    r_mode = int(custom_mode(pixels[:, 2]))
    return (b_mode, g_mode, r_mode)  # Increase brightness for visibility

# Generate ColorPalette with BGR colors based on sorted mask order
sorted_mask_colors = [
    Color.from_bgr_tuple(get_most_common_color(image_bgr, mask)) for mask in sorted_masks
]
custom_color_palette = ColorPalette(colors=sorted_mask_colors)

# Convert filtered SAM result to detections and annotate using the sorted colors
detections = sv.Detections.from_sam(sam_result=filtered_sam_result)
mask_annotator = sv.MaskAnnotator(color=custom_color_palette, opacity=0.9)

# Create a custom color lookup array based on sorted colors
custom_color_lookup = np.arange(len(sorted_mask_colors))

try:
    # Annotate the image with the custom color palette in BGR
    annotated_image_with_custom_colors = mask_annotator.annotate(
        scene=image_bgr.copy(),  # Input image in BGR
        detections=detections,
        custom_color_lookup=custom_color_lookup
    )

    # Display the original and annotated images
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB))  # Convert for display only
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(annotated_image_with_custom_colors, cv2.COLOR_BGR2RGB))  # Convert for display
    plt.title("Annotated Image with Filtered Masks")
    plt.axis("off")

    plt.show()

except AssertionError as ae:
    print(f"Assertion error: {ae}")
except Exception as e:
    print(f"Error during annotation: {e}")"""
# Out:
# 'sorted_masks = [mask for _, mask, _, _ in filtered_masks_with_areas_and_bboxes]\n\n# Define custom function to find the mode of an array\ndef custom_mode(array):\n    values, counts = np.unique(array, return_counts=True)\n    return values[np.argmax(counts)]\n\n# Function to get the most common color within a masked area\ndef get_most_common_color(image_bgr, mask):\n    mask_area = np.where(mask)\n    pixels = image_bgr[mask_area]\n    if pixels.size == 0 or pixels.ndim != 2 or pixels.shape[1] != 3:\n        return (0, 0, 0)\n\n    # Use custom mode for each channel (BGR order)\n    b_mode = int(custom_mode(pixels[:, 0]))\n    g_mode = int(custom_mode(pixels[:, 1]))\n    r_mode = int(custom_mode(pixels[:, 2]))\n    return (b_mode, g_mode, r_mode)  # Increase brightness for visibility\n\n# Generate ColorPalette with BGR colors based on sorted mask order\nsorted_mask_colors = [\n    Color.from_bgr_tuple(get_most_common_color(image_bgr, mask)) for mask in sorted_masks\n]\ncustom_color_palette = ColorPalette(colors=sorted_mask_colors)\n\n# Convert filtered SAM result to detections and annotate using the sorted colors\ndetections = sv.Detections.from_sam(sam_result=filtered_sam_result)\nmask_annotator = sv.MaskAnnotator(color=custom_color_palette, opacity=0.9)\n\n# Create a custom color lookup array based on sorted colors\ncustom_color_lookup = np.arange(len(sorted_mask_colors))\n\ntry:\n    # Annotate the image with the custom color palette in BGR\n    annotated_image_with_custom_colors = mask_annotator.annotate(\n        scene=image_bgr.copy(),  # Input image in BGR\n        detections=detections,\n        custom_color_lookup=custom_color_lookup\n    )\n\n    # Display the original and annotated images\n    plt.figure(figsize=(12, 6))\n    plt.subplot(1, 2, 1)\n    plt.imshow(cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB))  # Convert for display only\n    plt.title("Original Image")\n    plt.axis("off")\n\n    plt.subplot(1, 2, 2)\n    plt.imshow(cv2.cvtColor(annotated_image_with_custom_colors, cv2.COLOR_BGR2RGB))  # Convert for display\n    plt.title("Annotated Image with Filtered Masks")\n    plt.axis("off")\n\n    plt.show()\n\nexcept AssertionError as ae:\n    print(f"Assertion error: {ae}")\nexcept Exception as e:\n    print(f"Error during annotation: {e}")'

# %%
from shapely.geometry import MultiPolygon

polygons_list = []

# Prepare a copy of the original image for drawing polygons
image_with_polygons = image_bgr.copy()

# Image area
image_area = image_bgr.shape[0] * image_bgr.shape[1]

# List to store polygons with their area
mask_polygons = []

# Function to smooth contour using moving average
def smooth_contour(contour, window_size=5):
    # Ensure window_size is odd
    if window_size % 2 == 0:
        window_size += 1
    half_window = window_size // 2

    # Pad the contour to handle the circular nature
    contour = np.concatenate((contour[-half_window:], contour, contour[:half_window]), axis=0)
    
    smoothed_contour = []
    for i in range(half_window, len(contour) - half_window):
        window_points = contour[i - half_window:i + half_window + 1]
        mean_point = np.mean(window_points, axis=0)
        smoothed_contour.append(mean_point)
    smoothed_contour = np.array(smoothed_contour, dtype=np.int32)
    return smoothed_contour

# Loop over each mask in the filtered SAM result
for idx, mask_dict in enumerate(filtered_sam_result):
    mask = mask_dict['segmentation'].astype(np.uint8)  # Ensure mask is in uint8 format

    # Find contours in the mask
    contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # Skip if no contours are found
    if not contours:
        continue

    # Process each contour
    for contour in contours:
        if contour.shape[0] < 5:
            continue  # Need at least 5 points to smooth

        # Reshape contour to 2D array
        contour = contour.reshape(-1, 2)

        # Smooth the contour using moving average
        smoothed_contour = smooth_contour(contour, window_size=15)  # Adjust window_size as needed

        if smoothed_contour.shape[0] >= 3:
            polygon = Polygon(smoothed_contour)
            # Ensure the polygon is valid
            if not polygon.is_valid or polygon.area == 0:
                # Try fixing invalid polygons
                polygon = polygon.buffer(0)
                if not polygon.is_valid or polygon.area == 0:
                    continue  # Skip if still invalid
            # Store the polygon along with its area and index
            mask_polygons.append({'area': polygon.area, 'polygon': polygon, 'index': idx})

# Introduce max_area_threshold to exclude overly large polygons
max_area_threshold = 0.9 * image_area  # Exclude polygons covering more than 90% of the image

# Filter out masks that are too large
mask_polygons = [mp for mp in mask_polygons if mp['area'] < max_area_threshold]

# Debug: Print the number of polygons after excluding large masks
print(f"Total polygons after excluding large masks: {len(mask_polygons)}")

# Now, filter out smaller polygons that are mostly within larger ones
# Sort polygons by area in descending order
mask_polygons.sort(key=lambda x: x['area'], reverse=True)

# Initialize list to hold the final polygons
filtered_polygons = []

# Function to check if a polygon is mostly within existing polygons
def is_polygon_mostly_within(poly, existing_polys, area_overlap_threshold=0.95):
    for existing_poly in existing_polys:
        intersection_area = poly.intersection(existing_poly).area
        if poly.area == 0:
            continue
        overlap_ratio = intersection_area / poly.area
        if overlap_ratio >= area_overlap_threshold:
            return True
    return False

# Process each polygon
for idx, poly_dict in enumerate(mask_polygons):
    poly = poly_dict['polygon']
    if not is_polygon_mostly_within(poly, [d['polygon'] for d in filtered_polygons], area_overlap_threshold=0.95):
        filtered_polygons.append(poly_dict)
    else:
        print(f"Polygon {idx} is mostly within another polygon and will be removed.")

# Debug: Print the number of polygons after filtering
print(f"Total polygons after overlap filtering: {len(filtered_polygons)}")

# Draw the filtered polygons on the image
for poly_dict in filtered_polygons:
    poly = poly_dict['polygon']
    if isinstance(poly, Polygon):
        # Handle single Polygon
        coords = np.array(list(poly.exterior.coords)).astype(np.int32)
        cv2.polylines(image_with_polygons, [coords], isClosed=True, color=(0, 255, 0), thickness=5)
        polygons_list.append(poly)
    elif isinstance(poly, MultiPolygon):
        # Handle MultiPolygon
        for sub_poly in poly.geoms:
            if sub_poly.is_valid and not sub_poly.is_empty:
                coords = np.array(list(sub_poly.exterior.coords)).astype(np.int32)
                cv2.polylines(image_with_polygons, [coords], isClosed=True, color=(0, 255, 0), thickness=5)
                polygons_list.append(sub_poly)

# Display the image with vectorized polygons
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image_with_polygons, cv2.COLOR_BGR2RGB))
plt.title("Image with Filtered Polygons (Smoothed Contours)")
plt.axis("off")
plt.show()
# Out:
# Total polygons after excluding large masks: 569
# Polygon 1 is mostly within another polygon and will be removed.
# Polygon 3 is mostly within another polygon and will be removed.
# Polygon 6 is mostly within another polygon and will be removed.
# Polygon 7 is mostly within another polygon and will be removed.
# Polygon 8 is mostly within another polygon and will be removed.
# Polygon 13 is mostly within another polygon and will be removed.
# Polygon 15 is mostly within another polygon and will be removed.
# Polygon 19 is mostly within another polygon and will be removed.
# Polygon 20 is mostly within another polygon and will be removed.
# Polygon 22 is mostly within another polygon and will be removed.
# Polygon 23 is mostly within another polygon and will be removed.
# Polygon 26 is mostly within another polygon and will be removed.
# Polygon 31 is mostly within another polygon and will be removed.
# Polygon 32 is mostly within another polygon and will be removed.
# Polygon 34 is mostly within another polygon and will be removed.
# Polygon 36 is mostly within another polygon and will be removed.
# Polygon 37 is mostly within another polygon and will be removed.
# Polygon 38 is mostly within another polygon and will be removed.
# Polygon 39 is mostly within another polygon and will be removed.
# Polygon 41 is mostly within another polygon and will be removed.
# Polygon 43 is mostly within another polygon and will be removed.
# Polygon 45 is mostly within another polygon and will be removed.
# Polygon 46 is mostly within another polygon and will be removed.
# Polygon 48 is mostly within another polygon and will be removed.
# Polygon 50 is mostly within another polygon and will be removed.
# Polygon 51 is mostly within another polygon and will be removed.
# Polygon 52 is mostly within another polygon and will be removed.
# Polygon 55 is mostly within another polygon and will be removed.
# Polygon 57 is mostly within another polygon and will be removed.
# Polygon 58 is mostly within another polygon and will be removed.
# Polygon 61 is mostly within another polygon and will be removed.
# Polygon 62 is mostly within another polygon and will be removed.
# Polygon 63 is mostly within another polygon and will be removed.
# Polygon 64 is mostly within another polygon and will be removed.
# Polygon 65 is mostly within another polygon and will be removed.
# Polygon 66 is mostly within another polygon and will be removed.
# Polygon 68 is mostly within another polygon and will be removed.
# Polygon 69 is mostly within another polygon and will be removed.
# Polygon 70 is mostly within another polygon and will be removed.
# Polygon 71 is mostly within another polygon and will be removed.
# Polygon 73 is mostly within another polygon and will be removed.
# Polygon 75 is mostly within another polygon and will be removed.
# Polygon 79 is mostly within another polygon and will be removed.
# Polygon 80 is mostly within another polygon and will be removed.
# Polygon 82 is mostly within another polygon and will be removed.
# Polygon 83 is mostly within another polygon and will be removed.
# Polygon 86 is mostly within another polygon and will be removed.
# Polygon 87 is mostly within another polygon and will be removed.
# Polygon 88 is mostly within another polygon and will be removed.
# Polygon 89 is mostly within another polygon and will be removed.
# Polygon 90 is mostly within another polygon and will be removed.
# Polygon 91 is mostly within another polygon and will be removed.
# Polygon 93 is mostly within another polygon and will be removed.
# Polygon 95 is mostly within another polygon and will be removed.
# Polygon 97 is mostly within another polygon and will be removed.
# Polygon 98 is mostly within another polygon and will be removed.
# Polygon 100 is mostly within another polygon and will be removed.
# Polygon 101 is mostly within another polygon and will be removed.
# Polygon 102 is mostly within another polygon and will be removed.
# Polygon 103 is mostly within another polygon and will be removed.
# Polygon 104 is mostly within another polygon and will be removed.
# Polygon 105 is mostly within another polygon and will be removed.
# Polygon 106 is mostly within another polygon and will be removed.
# Polygon 108 is mostly within another polygon and will be removed.
# Polygon 110 is mostly within another polygon and will be removed.
# Polygon 111 is mostly within another polygon and will be removed.
# Polygon 113 is mostly within another polygon and will be removed.
# Polygon 114 is mostly within another polygon and will be removed.
# Polygon 115 is mostly within another polygon and will be removed.
# Polygon 118 is mostly within another polygon and will be removed.
# Polygon 119 is mostly within another polygon and will be removed.
# Polygon 121 is mostly within another polygon and will be removed.
# Polygon 122 is mostly within another polygon and will be removed.
# Polygon 125 is mostly within another polygon and will be removed.
# Polygon 127 is mostly within another polygon and will be removed.
# Polygon 129 is mostly within another polygon and will be removed.
# Polygon 130 is mostly within another polygon and will be removed.
# Polygon 131 is mostly within another polygon and will be removed.
# Polygon 132 is mostly within another polygon and will be removed.
# Polygon 133 is mostly within another polygon and will be removed.
# Polygon 134 is mostly within another polygon and will be removed.
# Polygon 135 is mostly within another polygon and will be removed.
# Polygon 136 is mostly within another polygon and will be removed.
# Polygon 137 is mostly within another polygon and will be removed.
# Polygon 138 is mostly within another polygon and will be removed.
# Polygon 139 is mostly within another polygon and will be removed.
# Polygon 140 is mostly within another polygon and will be removed.
# Polygon 141 is mostly within another polygon and will be removed.
# Polygon 143 is mostly within another polygon and will be removed.
# Polygon 146 is mostly within another polygon and will be removed.
# Polygon 149 is mostly within another polygon and will be removed.
# Polygon 151 is mostly within another polygon and will be removed.
# Polygon 152 is mostly within another polygon and will be removed.
# Polygon 153 is mostly within another polygon and will be removed.
# Polygon 155 is mostly within another polygon and will be removed.
# Polygon 156 is mostly within another polygon and will be removed.
# Polygon 157 is mostly within another polygon and will be removed.
# Polygon 158 is mostly within another polygon and will be removed.
# Polygon 159 is mostly within another polygon and will be removed.
# Polygon 160 is mostly within another polygon and will be removed.
# Polygon 162 is mostly within another polygon and will be removed.
# Polygon 163 is mostly within another polygon and will be removed.
# Polygon 164 is mostly within another polygon and will be removed.
# Polygon 165 is mostly within another polygon and will be removed.
# Polygon 166 is mostly within another polygon and will be removed.
# Polygon 167 is mostly within another polygon and will be removed.
# Polygon 168 is mostly within another polygon and will be removed.
# Polygon 169 is mostly within another polygon and will be removed.
# Polygon 170 is mostly within another polygon and will be removed.
# Polygon 172 is mostly within another polygon and will be removed.
# Polygon 174 is mostly within another polygon and will be removed.
# Polygon 175 is mostly within another polygon and will be removed.
# Polygon 176 is mostly within another polygon and will be removed.
# Polygon 177 is mostly within another polygon and will be removed.
# Polygon 178 is mostly within another polygon and will be removed.
# Polygon 179 is mostly within another polygon and will be removed.
# Polygon 180 is mostly within another polygon and will be removed.
# Polygon 181 is mostly within another polygon and will be removed.
# Polygon 182 is mostly within another polygon and will be removed.
# Polygon 183 is mostly within another polygon and will be removed.
# Polygon 184 is mostly within another polygon and will be removed.
# Polygon 185 is mostly within another polygon and will be removed.
# Polygon 186 is mostly within another polygon and will be removed.
# Polygon 187 is mostly within another polygon and will be removed.
# Polygon 188 is mostly within another polygon and will be removed.
# Polygon 190 is mostly within another polygon and will be removed.
# Polygon 191 is mostly within another polygon and will be removed.
# Polygon 192 is mostly within another polygon and will be removed.
# Polygon 193 is mostly within another polygon and will be removed.
# Polygon 194 is mostly within another polygon and will be removed.
# Polygon 195 is mostly within another polygon and will be removed.
# Polygon 196 is mostly within another polygon and will be removed.
# Polygon 197 is mostly within another polygon and will be removed.
# Polygon 198 is mostly within another polygon and will be removed.
# Polygon 199 is mostly within another polygon and will be removed.
# Polygon 200 is mostly within another polygon and will be removed.
# Polygon 201 is mostly within another polygon and will be removed.
# Polygon 202 is mostly within another polygon and will be removed.
# Polygon 203 is mostly within another polygon and will be removed.
# Polygon 204 is mostly within another polygon and will be removed.
# Polygon 206 is mostly within another polygon and will be removed.
# Polygon 207 is mostly within another polygon and will be removed.
# Polygon 208 is mostly within another polygon and will be removed.
# Polygon 209 is mostly within another polygon and will be removed.
# Polygon 211 is mostly within another polygon and will be removed.
# Polygon 212 is mostly within another polygon and will be removed.
# Polygon 214 is mostly within another polygon and will be removed.
# Polygon 215 is mostly within another polygon and will be removed.
# Polygon 216 is mostly within another polygon and will be removed.
# Polygon 217 is mostly within another polygon and will be removed.
# Polygon 219 is mostly within another polygon and will be removed.
# Polygon 220 is mostly within another polygon and will be removed.
# Polygon 221 is mostly within another polygon and will be removed.
# Polygon 222 is mostly within another polygon and will be removed.
# Polygon 224 is mostly within another polygon and will be removed.
# Polygon 225 is mostly within another polygon and will be removed.
# Polygon 226 is mostly within another polygon and will be removed.
# Polygon 227 is mostly within another polygon and will be removed.
# Polygon 228 is mostly within another polygon and will be removed.
# Polygon 230 is mostly within another polygon and will be removed.
# Polygon 231 is mostly within another polygon and will be removed.
# Polygon 232 is mostly within another polygon and will be removed.
# Polygon 233 is mostly within another polygon and will be removed.
# Polygon 234 is mostly within another polygon and will be removed.
# Polygon 235 is mostly within another polygon and will be removed.
# Polygon 236 is mostly within another polygon and will be removed.
# Polygon 237 is mostly within another polygon and will be removed.
# Polygon 238 is mostly within another polygon and will be removed.
# Polygon 240 is mostly within another polygon and will be removed.
# Polygon 241 is mostly within another polygon and will be removed.
# Polygon 242 is mostly within another polygon and will be removed.
# Polygon 243 is mostly within another polygon and will be removed.
# Polygon 244 is mostly within another polygon and will be removed.
# Polygon 245 is mostly within another polygon and will be removed.
# Polygon 246 is mostly within another polygon and will be removed.
# Polygon 247 is mostly within another polygon and will be removed.
# Polygon 248 is mostly within another polygon and will be removed.
# Polygon 249 is mostly within another polygon and will be removed.
# Polygon 251 is mostly within another polygon and will be removed.
# Polygon 252 is mostly within another polygon and will be removed.
# Polygon 253 is mostly within another polygon and will be removed.
# Polygon 254 is mostly within another polygon and will be removed.
# Polygon 255 is mostly within another polygon and will be removed.
# Polygon 256 is mostly within another polygon and will be removed.
# Polygon 257 is mostly within another polygon and will be removed.
# Polygon 258 is mostly within another polygon and will be removed.
# Polygon 259 is mostly within another polygon and will be removed.
# Polygon 261 is mostly within another polygon and will be removed.
# Polygon 262 is mostly within another polygon and will be removed.
# Polygon 263 is mostly within another polygon and will be removed.
# Polygon 265 is mostly within another polygon and will be removed.
# Polygon 266 is mostly within another polygon and will be removed.
# Polygon 267 is mostly within another polygon and will be removed.
# Polygon 268 is mostly within another polygon and will be removed.
# Polygon 269 is mostly within another polygon and will be removed.
# Polygon 271 is mostly within another polygon and will be removed.
# Polygon 272 is mostly within another polygon and will be removed.
# Polygon 273 is mostly within another polygon and will be removed.
# Polygon 274 is mostly within another polygon and will be removed.
# Polygon 275 is mostly within another polygon and will be removed.
# Polygon 276 is mostly within another polygon and will be removed.
# Polygon 277 is mostly within another polygon and will be removed.
# Polygon 278 is mostly within another polygon and will be removed.
# Polygon 279 is mostly within another polygon and will be removed.
# Polygon 280 is mostly within another polygon and will be removed.
# Polygon 281 is mostly within another polygon and will be removed.
# Polygon 282 is mostly within another polygon and will be removed.
# Polygon 283 is mostly within another polygon and will be removed.
# Polygon 284 is mostly within another polygon and will be removed.
# Polygon 285 is mostly within another polygon and will be removed.
# Polygon 286 is mostly within another polygon and will be removed.
# Polygon 287 is mostly within another polygon and will be removed.
# Polygon 288 is mostly within another polygon and will be removed.
# Polygon 291 is mostly within another polygon and will be removed.
# Polygon 292 is mostly within another polygon and will be removed.
# Polygon 293 is mostly within another polygon and will be removed.
# Polygon 294 is mostly within another polygon and will be removed.
# Polygon 295 is mostly within another polygon and will be removed.
# Polygon 296 is mostly within another polygon and will be removed.
# Polygon 297 is mostly within another polygon and will be removed.
# Polygon 298 is mostly within another polygon and will be removed.
# Polygon 299 is mostly within another polygon and will be removed.
# Polygon 300 is mostly within another polygon and will be removed.
# Polygon 301 is mostly within another polygon and will be removed.
# Polygon 302 is mostly within another polygon and will be removed.
# Polygon 304 is mostly within another polygon and will be removed.
# Polygon 305 is mostly within another polygon and will be removed.
# Polygon 306 is mostly within another polygon and will be removed.
# Polygon 307 is mostly within another polygon and will be removed.
# Polygon 308 is mostly within another polygon and will be removed.
# Polygon 310 is mostly within another polygon and will be removed.
# Polygon 311 is mostly within another polygon and will be removed.
# Polygon 312 is mostly within another polygon and will be removed.
# Polygon 313 is mostly within another polygon and will be removed.
# Polygon 314 is mostly within another polygon and will be removed.
# Polygon 315 is mostly within another polygon and will be removed.
# Polygon 316 is mostly within another polygon and will be removed.
# Polygon 317 is mostly within another polygon and will be removed.
# Polygon 318 is mostly within another polygon and will be removed.
# Polygon 319 is mostly within another polygon and will be removed.
# Polygon 320 is mostly within another polygon and will be removed.
# Polygon 321 is mostly within another polygon and will be removed.
# Polygon 323 is mostly within another polygon and will be removed.
# Polygon 324 is mostly within another polygon and will be removed.
# Polygon 325 is mostly within another polygon and will be removed.
# Polygon 326 is mostly within another polygon and will be removed.
# Polygon 327 is mostly within another polygon and will be removed.
# Polygon 328 is mostly within another polygon and will be removed.
# Polygon 329 is mostly within another polygon and will be removed.
# Polygon 330 is mostly within another polygon and will be removed.
# Polygon 331 is mostly within another polygon and will be removed.
# Polygon 332 is mostly within another polygon and will be removed.
# Polygon 333 is mostly within another polygon and will be removed.
# Polygon 334 is mostly within another polygon and will be removed.
# Polygon 335 is mostly within another polygon and will be removed.
# Polygon 336 is mostly within another polygon and will be removed.
# Polygon 337 is mostly within another polygon and will be removed.
# Polygon 338 is mostly within another polygon and will be removed.
# Polygon 339 is mostly within another polygon and will be removed.
# Polygon 340 is mostly within another polygon and will be removed.
# Polygon 341 is mostly within another polygon and will be removed.
# Polygon 342 is mostly within another polygon and will be removed.
# Polygon 343 is mostly within another polygon and will be removed.
# Polygon 345 is mostly within another polygon and will be removed.
# Polygon 346 is mostly within another polygon and will be removed.
# Polygon 347 is mostly within another polygon and will be removed.
# Polygon 348 is mostly within another polygon and will be removed.
# Polygon 349 is mostly within another polygon and will be removed.
# Polygon 350 is mostly within another polygon and will be removed.
# Polygon 351 is mostly within another polygon and will be removed.
# Polygon 352 is mostly within another polygon and will be removed.
# Polygon 353 is mostly within another polygon and will be removed.
# Polygon 354 is mostly within another polygon and will be removed.
# Polygon 355 is mostly within another polygon and will be removed.
# Polygon 356 is mostly within another polygon and will be removed.
# Polygon 358 is mostly within another polygon and will be removed.
# Polygon 360 is mostly within another polygon and will be removed.
# Polygon 361 is mostly within another polygon and will be removed.
# Polygon 362 is mostly within another polygon and will be removed.
# Polygon 363 is mostly within another polygon and will be removed.
# Polygon 365 is mostly within another polygon and will be removed.
# Polygon 367 is mostly within another polygon and will be removed.
# Polygon 368 is mostly within another polygon and will be removed.
# Polygon 369 is mostly within another polygon and will be removed.
# Polygon 370 is mostly within another polygon and will be removed.
# Polygon 372 is mostly within another polygon and will be removed.
# Polygon 373 is mostly within another polygon and will be removed.
# Polygon 374 is mostly within another polygon and will be removed.
# Polygon 375 is mostly within another polygon and will be removed.
# Polygon 376 is mostly within another polygon and will be removed.
# Polygon 377 is mostly within another polygon and will be removed.
# Polygon 378 is mostly within another polygon and will be removed.
# Polygon 379 is mostly within another polygon and will be removed.
# Polygon 380 is mostly within another polygon and will be removed.
# Polygon 382 is mostly within another polygon and will be removed.
# Polygon 383 is mostly within another polygon and will be removed.
# Polygon 385 is mostly within another polygon and will be removed.
# Polygon 386 is mostly within another polygon and will be removed.
# Polygon 387 is mostly within another polygon and will be removed.
# Polygon 388 is mostly within another polygon and will be removed.
# Polygon 389 is mostly within another polygon and will be removed.
# Polygon 390 is mostly within another polygon and will be removed.
# Polygon 391 is mostly within another polygon and will be removed.
# Polygon 392 is mostly within another polygon and will be removed.
# Polygon 393 is mostly within another polygon and will be removed.
# Polygon 394 is mostly within another polygon and will be removed.
# Polygon 395 is mostly within another polygon and will be removed.
# Polygon 397 is mostly within another polygon and will be removed.
# Polygon 398 is mostly within another polygon and will be removed.
# Polygon 399 is mostly within another polygon and will be removed.
# Polygon 400 is mostly within another polygon and will be removed.
# Polygon 401 is mostly within another polygon and will be removed.
# Polygon 402 is mostly within another polygon and will be removed.
# Polygon 403 is mostly within another polygon and will be removed.
# Polygon 404 is mostly within another polygon and will be removed.
# Polygon 405 is mostly within another polygon and will be removed.
# Polygon 406 is mostly within another polygon and will be removed.
# Polygon 407 is mostly within another polygon and will be removed.
# Polygon 408 is mostly within another polygon and will be removed.
# Polygon 409 is mostly within another polygon and will be removed.
# Polygon 410 is mostly within another polygon and will be removed.
# Polygon 411 is mostly within another polygon and will be removed.
# Polygon 412 is mostly within another polygon and will be removed.
# Polygon 413 is mostly within another polygon and will be removed.
# Polygon 414 is mostly within another polygon and will be removed.
# Polygon 415 is mostly within another polygon and will be removed.
# Polygon 417 is mostly within another polygon and will be removed.
# Polygon 418 is mostly within another polygon and will be removed.
# Polygon 419 is mostly within another polygon and will be removed.
# Polygon 420 is mostly within another polygon and will be removed.
# Polygon 422 is mostly within another polygon and will be removed.
# Polygon 423 is mostly within another polygon and will be removed.
# Polygon 424 is mostly within another polygon and will be removed.
# Polygon 425 is mostly within another polygon and will be removed.
# Polygon 426 is mostly within another polygon and will be removed.
# Polygon 427 is mostly within another polygon and will be removed.
# Polygon 428 is mostly within another polygon and will be removed.
# Polygon 429 is mostly within another polygon and will be removed.
# Polygon 430 is mostly within another polygon and will be removed.
# Polygon 431 is mostly within another polygon and will be removed.
# Polygon 432 is mostly within another polygon and will be removed.
# Polygon 433 is mostly within another polygon and will be removed.
# Polygon 434 is mostly within another polygon and will be removed.
# Polygon 435 is mostly within another polygon and will be removed.
# Polygon 436 is mostly within another polygon and will be removed.
# Polygon 437 is mostly within another polygon and will be removed.
# Polygon 438 is mostly within another polygon and will be removed.
# Polygon 439 is mostly within another polygon and will be removed.
# Polygon 440 is mostly within another polygon and will be removed.
# Polygon 442 is mostly within another polygon and will be removed.
# Polygon 443 is mostly within another polygon and will be removed.
# Polygon 444 is mostly within another polygon and will be removed.
# Polygon 445 is mostly within another polygon and will be removed.
# Polygon 447 is mostly within another polygon and will be removed.
# Polygon 448 is mostly within another polygon and will be removed.
# Polygon 449 is mostly within another polygon and will be removed.
# Polygon 450 is mostly within another polygon and will be removed.
# Polygon 451 is mostly within another polygon and will be removed.
# Polygon 453 is mostly within another polygon and will be removed.
# Polygon 454 is mostly within another polygon and will be removed.
# Polygon 455 is mostly within another polygon and will be removed.
# Polygon 456 is mostly within another polygon and will be removed.
# Polygon 457 is mostly within another polygon and will be removed.
# Polygon 458 is mostly within another polygon and will be removed.
# Polygon 459 is mostly within another polygon and will be removed.
# Polygon 460 is mostly within another polygon and will be removed.
# Polygon 461 is mostly within another polygon and will be removed.
# Polygon 463 is mostly within another polygon and will be removed.
# Polygon 464 is mostly within another polygon and will be removed.
# Polygon 465 is mostly within another polygon and will be removed.
# Polygon 466 is mostly within another polygon and will be removed.
# Polygon 467 is mostly within another polygon and will be removed.
# Polygon 468 is mostly within another polygon and will be removed.
# Polygon 469 is mostly within another polygon and will be removed.
# Polygon 470 is mostly within another polygon and will be removed.
# Polygon 471 is mostly within another polygon and will be removed.
# Polygon 472 is mostly within another polygon and will be removed.
# Polygon 473 is mostly within another polygon and will be removed.
# Polygon 474 is mostly within another polygon and will be removed.
# Polygon 475 is mostly within another polygon and will be removed.
# Polygon 476 is mostly within another polygon and will be removed.
# Polygon 477 is mostly within another polygon and will be removed.
# Polygon 478 is mostly within another polygon and will be removed.
# Polygon 479 is mostly within another polygon and will be removed.
# Polygon 480 is mostly within another polygon and will be removed.
# Polygon 481 is mostly within another polygon and will be removed.
# Polygon 482 is mostly within another polygon and will be removed.
# Polygon 483 is mostly within another polygon and will be removed.
# Polygon 484 is mostly within another polygon and will be removed.
# Polygon 485 is mostly within another polygon and will be removed.
# Polygon 486 is mostly within another polygon and will be removed.
# Polygon 487 is mostly within another polygon and will be removed.
# Polygon 488 is mostly within another polygon and will be removed.
# Polygon 489 is mostly within another polygon and will be removed.
# Polygon 490 is mostly within another polygon and will be removed.
# Polygon 491 is mostly within another polygon and will be removed.
# Polygon 492 is mostly within another polygon and will be removed.
# Polygon 493 is mostly within another polygon and will be removed.
# Polygon 494 is mostly within another polygon and will be removed.
# Polygon 495 is mostly within another polygon and will be removed.
# Polygon 496 is mostly within another polygon and will be removed.
# Polygon 497 is mostly within another polygon and will be removed.
# Polygon 498 is mostly within another polygon and will be removed.
# Polygon 499 is mostly within another polygon and will be removed.
# Polygon 500 is mostly within another polygon and will be removed.
# Polygon 501 is mostly within another polygon and will be removed.
# Polygon 502 is mostly within another polygon and will be removed.
# Polygon 504 is mostly within another polygon and will be removed.
# Polygon 505 is mostly within another polygon and will be removed.
# Polygon 506 is mostly within another polygon and will be removed.
# Polygon 507 is mostly within another polygon and will be removed.
# Polygon 508 is mostly within another polygon and will be removed.
# Polygon 509 is mostly within another polygon and will be removed.
# Polygon 510 is mostly within another polygon and will be removed.
# Polygon 511 is mostly within another polygon and will be removed.
# Polygon 513 is mostly within another polygon and will be removed.
# Polygon 514 is mostly within another polygon and will be removed.
# Polygon 515 is mostly within another polygon and will be removed.
# Polygon 516 is mostly within another polygon and will be removed.
# Polygon 517 is mostly within another polygon and will be removed.
# Polygon 518 is mostly within another polygon and will be removed.
# Polygon 519 is mostly within another polygon and will be removed.
# Polygon 520 is mostly within another polygon and will be removed.
# Polygon 521 is mostly within another polygon and will be removed.
# Polygon 523 is mostly within another polygon and will be removed.
# Polygon 524 is mostly within another polygon and will be removed.
# Polygon 525 is mostly within another polygon and will be removed.
# Polygon 526 is mostly within another polygon and will be removed.
# Polygon 527 is mostly within another polygon and will be removed.
# Polygon 528 is mostly within another polygon and will be removed.
# Polygon 529 is mostly within another polygon and will be removed.
# Polygon 530 is mostly within another polygon and will be removed.
# Polygon 531 is mostly within another polygon and will be removed.
# Polygon 532 is mostly within another polygon and will be removed.
# Polygon 533 is mostly within another polygon and will be removed.
# Polygon 534 is mostly within another polygon and will be removed.
# Polygon 535 is mostly within another polygon and will be removed.
# Polygon 536 is mostly within another polygon and will be removed.
# Polygon 537 is mostly within another polygon and will be removed.
# Polygon 538 is mostly within another polygon and will be removed.
# Polygon 539 is mostly within another polygon and will be removed.
# Polygon 540 is mostly within another polygon and will be removed.
# Polygon 541 is mostly within another polygon and will be removed.
# Polygon 542 is mostly within another polygon and will be removed.
# Polygon 543 is mostly within another polygon and will be removed.
# Polygon 544 is mostly within another polygon and will be removed.
# Polygon 545 is mostly within another polygon and will be removed.
# Polygon 546 is mostly within another polygon and will be removed.
# Polygon 547 is mostly within another polygon and will be removed.
# Polygon 549 is mostly within another polygon and will be removed.
# Polygon 550 is mostly within another polygon and will be removed.
# Polygon 551 is mostly within another polygon and will be removed.
# Polygon 552 is mostly within another polygon and will be removed.
# Polygon 553 is mostly within another polygon and will be removed.
# Polygon 554 is mostly within another polygon and will be removed.
# Polygon 556 is mostly within another polygon and will be removed.
# Polygon 557 is mostly within another polygon and will be removed.
# Polygon 558 is mostly within another polygon and will be removed.
# Polygon 559 is mostly within another polygon and will be removed.
# Polygon 560 is mostly within another polygon and will be removed.
# Polygon 561 is mostly within another polygon and will be removed.
# Polygon 562 is mostly within another polygon and will be removed.
# Polygon 563 is mostly within another polygon and will be removed.
# Polygon 564 is mostly within another polygon and will be removed.
# Polygon 565 is mostly within another polygon and will be removed.
# Polygon 566 is mostly within another polygon and will be removed.
# Polygon 567 is mostly within another polygon and will be removed.
# Polygon 568 is mostly within another polygon and will be removed.
# Total polygons after overlap filtering: 101
